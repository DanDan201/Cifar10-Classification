# %%
# %matplotlib inline

# %%
import torch
from torch import nn, optim
from torchsummary import summary
import torchvision
import numpy as np
import torchvision.transforms as T
import matplotlib.pyplot as plt
import os

os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Device: {}".format(device))
# Out:
# Device: cuda:0

# %%
augs = torchvision.transforms.Compose([
    T.RandomRotation(degrees = 15),
    # T.Resize((40,40)),
    # T.RandomResizedCrop((32,32), scale = (0.8,1), ratio=(1,1)),
    T.ColorJitter(brightness = 0.2,contrast = 0.2, saturation = 0.2, hue = 0.2),
    T.RandomHorizontalFlip(),
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225])
])

test_transform = T.Compose([
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# Load the Cifar10 dataset

# %%
batch_size_train = 128
batch_size_test = 128

train_data = torchvision.datasets.CIFAR10(root = './data',
                                          train = True,
                                          download=True,
                                          transform=augs)
test_data = torchvision.datasets.CIFAR10(root = './data',
                                          train = False,
                                          download=True,
                                          transform=test_transform)

train_loader = torch.utils.data.DataLoader(train_data,batch_size = batch_size_train, shuffle = True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size = batch_size_test, shuffle = True)
print(train_loader)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# <torch.utils.data.dataloader.DataLoader object at 0x000001461588B490>

# %%
def imshow(img):
    plt.figure(figsize=(2,2))
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg,(1,2,0)))

dataiter = iter(train_loader)
images, labels = next(dataiter)

for i in range(10):
    imshow(torchvision.utils.make_grid(images[i]))
    temp = augs(T.functional.to_pil_image(images[i]))
    imshow(torchvision.utils.make_grid(temp))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Create the model

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN,self).__init__()
        self.aug = augs
        self.conv1 = nn.Conv2d(in_channels = 3, out_channels = 64, kernel_size=(3,3), padding = 1)
        self.batchnorm1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(in_channels = 64, out_channels = 64, kernel_size=(3,3), padding = 1)
        self.batchnorm2 = nn.BatchNorm2d(64)

        self.conv3 = nn.Conv2d(in_channels = 64, out_channels = 128, kernel_size=(3,3), padding = 1)
        self.batchnorm3 = nn.BatchNorm2d(128)
        self.conv4 = nn.Conv2d(in_channels = 128, out_channels = 128, kernel_size=(3,3), padding = 1)
        self.batchnorm4 = nn.BatchNorm2d(128)

        self.conv5 = nn.Conv2d(in_channels = 128, out_channels = 256, kernel_size=(3,3), padding = 1)
        self.batchnorm5 = nn.BatchNorm2d(256)
        self.conv6 = nn.Conv2d(in_channels = 256, out_channels = 256, kernel_size=(3,3), padding = 1)
        self.batchnorm6 = nn.BatchNorm2d(256)
        self.conv7 = nn.Conv2d(in_channels = 256, out_channels = 256, kernel_size=(3,3), padding = 1)
        self.batchnorm7 = nn.BatchNorm2d(256)

        self.conv8 = nn.Conv2d(in_channels = 256, out_channels = 512, kernel_size=(3,3), padding = 1)
        self.batchnorm8 = nn.BatchNorm2d(512)
        self.conv9 = nn.Conv2d(in_channels = 512, out_channels = 512, kernel_size=(3,3), padding = 1)
        self.batchnorm9 = nn.BatchNorm2d(512)
        self.conv10 = nn.Conv2d(in_channels = 512, out_channels = 512, kernel_size = (3,3), padding = 1)
        self.batchnorm10 = nn.BatchNorm2d(512)

        self.conv11 = nn.Conv2d(in_channels = 512, out_channels = 512, kernel_size=(3,3), padding = 1)
        self.batchnorm11 = nn.BatchNorm2d(512)
        self.conv12 = nn.Conv2d(in_channels = 512, out_channels = 512, kernel_size=(3,3), padding = 1)
        self.batchnorm12 = nn.BatchNorm2d(512)
        self.conv13 = nn.Conv2d(in_channels = 512, out_channels = 512, kernel_size=(3,3), padding = 1)
        self.batchnorm13 = nn.BatchNorm2d(512)
        self.conv14 = nn.Conv2d(in_channels = 512, out_channels = 512, kernel_size=(3,3), padding = 1)
        self.batchnorm14 = nn.BatchNorm2d(512)

        # FC layers
        self.linear1 = nn.Linear(512,512, bias = True)
        self.dropout5 = nn.Dropout(p = 0.5)
        self.linear2 = nn.Linear(512,512, bias = True)
        self.linear3 = nn.Linear(512,10)
        self.softmax = nn.Softmax(-1)

        # Intermediate layers
        self.dropout2 = nn.Dropout(p = 0.2)
        self.dropout4 = nn.Dropout(p = 0.4)
        self.maxpool = nn.MaxPool2d(kernel_size=(2,2), stride=2)
        self.avgpool = nn.AvgPool2d(kernel_size=(2,2), stride=2)
        self.relu = nn.ReLU(inplace=True)
        self.flatten = nn.Flatten()

    def forward(self,x):
        x = self.relu(self.batchnorm1(self.conv1(x)))
        x = self.relu(self.batchnorm2(self.conv2(x)))
        x = self.maxpool(x)

        x = self.relu(self.batchnorm3(self.conv3(x)))
        x = self.relu(self.batchnorm4(self.conv4(x)))
        x = self.maxpool(x)

        x = self.relu(self.batchnorm5(self.conv5(x)))
        x = self.relu(self.batchnorm6(self.conv6(x)))
        x = self.relu(self.batchnorm7(self.conv7(x)))
        x = self.maxpool(x)

        x = self.relu(self.batchnorm8(self.conv8(x)))
        x = self.relu(self.batchnorm9(self.conv9(x)))
        x = self.relu(self.batchnorm10(self.conv10(x)))
        x = self.maxpool(x)

        x = self.relu(self.batchnorm11(self.conv11(x)))
        x = self.relu(self.batchnorm12(self.conv12(x)))
        x = self.relu(self.batchnorm13(self.conv13(x)))
        x = self.maxpool(x)
        # x = self.dropout5(x)

        x = self.flatten(x)
        x = self.linear1(x)
        x = self.relu(x)
        x = self.linear2(x)
        x = self.relu(x)
        # x = self.dropout5(x)
        x = self.linear3(x)

        return self.softmax(x)

model = CNN()
model.to(device)
summary(model, (3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#             Conv2d-4           [-1, 64, 32, 32]          36,928
#        BatchNorm2d-5           [-1, 64, 32, 32]             128
#               ReLU-6           [-1, 64, 32, 32]               0
#          MaxPool2d-7           [-1, 64, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]          73,856
#        BatchNorm2d-9          [-1, 128, 16, 16]             256
#              ReLU-10          [-1, 128, 16, 16]               0
#            Conv2d-11          [-1, 128, 16, 16]         147,584
#       BatchNorm2d-12          [-1, 128, 16, 16]             256
#              ReLU-13          [-1, 128, 16, 16]               0
#         MaxPool2d-14            [-1, 128, 8, 8]               0
#            Conv2d-15            [-1, 256, 8, 8]         295,168
#       BatchNorm2d-16            [-1, 256, 8, 8]             512
#              ReLU-17            [-1, 256, 8, 8]               0
#            Conv2d-18            [-1, 256, 8, 8]         590,080
#       BatchNorm2d-19            [-1, 256, 8, 8]             512
#              ReLU-20            [-1, 256, 8, 8]               0
#            Conv2d-21            [-1, 256, 8, 8]         590,080
#       BatchNorm2d-22            [-1, 256, 8, 8]             512
#              ReLU-23            [-1, 256, 8, 8]               0
#         MaxPool2d-24            [-1, 256, 4, 4]               0
#            Conv2d-25            [-1, 512, 4, 4]       1,180,160
#       BatchNorm2d-26            [-1, 512, 4, 4]           1,024
#              ReLU-27            [-1, 512, 4, 4]               0
#            Conv2d-28            [-1, 512, 4, 4]       2,359,808
#       BatchNorm2d-29            [-1, 512, 4, 4]           1,024
#              ReLU-30            [-1, 512, 4, 4]               0
#            Conv2d-31            [-1, 512, 4, 4]       2,359,808
#       BatchNorm2d-32            [-1, 512, 4, 4]           1,024
#              ReLU-33            [-1, 512, 4, 4]               0
#         MaxPool2d-34            [-1, 512, 2, 2]               0
#            Conv2d-35            [-1, 512, 2, 2]       2,359,808
#       BatchNorm2d-36            [-1, 512, 2, 2]           1,024
#              ReLU-37            [-1, 512, 2, 2]               0
#            Conv2d-38            [-1, 512, 2, 2]       2,359,808
#       BatchNorm2d-39            [-1, 512, 2, 2]           1,024
#              ReLU-40            [-1, 512, 2, 2]               0
#            Conv2d-41            [-1, 512, 2, 2]       2,359,808
#       BatchNorm2d-42            [-1, 512, 2, 2]           1,024
#              ReLU-43            [-1, 512, 2, 2]               0
#         MaxPool2d-44            [-1, 512, 1, 1]               0
#           Flatten-45                  [-1, 512]               0
#            Linear-46                  [-1, 512]         262,656
#              ReLU-47                  [-1, 512]               0
#            Linear-48                  [-1, 512]         262,656
#              ReLU-49                  [-1, 512]               0
#            Linear-50                   [-1, 10]           5,130
#           Softmax-51                   [-1, 10]               0
# ================================================================
# Total params: 15,253,578
# Trainable params: 15,253,578
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 6.59
# Params size (MB): 58.19
# Estimated Total Size (MB): 64.79
# ----------------------------------------------------------------

# %% [markdown]
# Initialize hyperparamters

# %%
optimizer = optim.SGD(model.parameters(), momentum = 0.9, lr = 0.01, weight_decay=1e-5)
loss_func = nn.CrossEntropyLoss(reduction = 'mean')
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience = 5)
num_epochs = 200

# %% [markdown]
# Train the model

# %%
train_acc_list = []
val_acc_list = []

train_loss_list = []
val_loss_list = []

es_count = 0
curr_epoch = 0
curr_loss = 0

for epoch in range(num_epochs):
    curr_epoch = epoch
    if es_count == 20:
        print("Stop training")
        break
    model.train()
    train_loss = 0
    train_acc = 0

    for inputs, labels in train_loader:

        inputs = inputs.to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_func(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        accuracy = (torch.max(outputs, dim=-1, keepdim=True)[1].flatten() == labels).sum() / len(labels)
        train_acc += accuracy.item()

    train_acc /= len(train_loader)
    train_loss /= len(train_loader)
    train_acc_list.append(train_acc)
    train_loss_list.append(train_loss)

    model.eval()
    test_acc = 0
    test_loss = 0

    with torch.no_grad():

        for inputs, labels in test_loader:

            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            loss = loss_func(outputs, labels)
            test_loss += loss.item()
            accuracy = (torch.max(outputs, dim=-1, keepdim=True)[1].flatten() == labels).sum() / len(labels)
            test_acc += accuracy.item()

        test_acc /= len(test_loader)
        test_loss /= len(test_loader)
        val_acc_list.append(test_acc)
        val_loss_list.append(test_loss)

        scheduler.step(test_loss)

    if abs(test_loss - curr_loss) < 0.005 or test_loss > curr_loss:
        es_count += 1
        curr_loss = test_loss
    else:
        es_count = 0
        curr_loss = test_loss

    print(f"Epoch {epoch + 1}/{num_epochs} - Training Loss: {train_loss:.4f} - Validation Loss: {test_loss:.4f}\n "
          f"Training Acc: {train_acc:.3f} - Validation Acc: {test_acc:.3f}")
# Out:
# Epoch 1/200 - Training Loss: 2.1244 - Validation Loss: 2.0079
#  Training Acc: 0.332 - Validation Acc: 0.449
# Epoch 2/200 - Training Loss: 1.9614 - Validation Loss: 1.9193
#  Training Acc: 0.496 - Validation Acc: 0.537
# Epoch 3/200 - Training Loss: 1.8911 - Validation Loss: 1.8830
#  Training Acc: 0.567 - Validation Acc: 0.575
# Epoch 4/200 - Training Loss: 1.8461 - Validation Loss: 1.8741
#  Training Acc: 0.612 - Validation Acc: 0.584
# Epoch 5/200 - Training Loss: 1.8144 - Validation Loss: 1.7754
#  Training Acc: 0.645 - Validation Acc: 0.683
# Epoch 6/200 - Training Loss: 1.7930 - Validation Loss: 1.7407
#  Training Acc: 0.666 - Validation Acc: 0.718
# Epoch 7/200 - Training Loss: 1.7773 - Validation Loss: 1.7515
#  Training Acc: 0.682 - Validation Acc: 0.709
# Epoch 8/200 - Training Loss: 1.7625 - Validation Loss: 1.7449
#  Training Acc: 0.697 - Validation Acc: 0.715
# Epoch 9/200 - Training Loss: 1.7511 - Validation Loss: 1.7418
#  Training Acc: 0.709 - Validation Acc: 0.718
# Epoch 10/200 - Training Loss: 1.7426 - Validation Loss: 1.7332
#  Training Acc: 0.717 - Validation Acc: 0.726
# Epoch 11/200 - Training Loss: 1.7330 - Validation Loss: 1.7064
#  Training Acc: 0.726 - Validation Acc: 0.752
# Epoch 12/200 - Training Loss: 1.7273 - Validation Loss: 1.7146
#  Training Acc: 0.732 - Validation Acc: 0.744
# Epoch 13/200 - Training Loss: 1.7201 - Validation Loss: 1.7015
#  Training Acc: 0.739 - Validation Acc: 0.758
# Epoch 14/200 - Training Loss: 1.7141 - Validation Loss: 1.6948
#  Training Acc: 0.746 - Validation Acc: 0.766
# Epoch 15/200 - Training Loss: 1.7080 - Validation Loss: 1.6928
#  Training Acc: 0.752 - Validation Acc: 0.767
# Epoch 16/200 - Training Loss: 1.7032 - Validation Loss: 1.6856
#  Training Acc: 0.757 - Validation Acc: 0.774
# Epoch 17/200 - Training Loss: 1.6987 - Validation Loss: 1.6678
#  Training Acc: 0.761 - Validation Acc: 0.793
# Epoch 18/200 - Training Loss: 1.6918 - Validation Loss: 1.6702
#  Training Acc: 0.768 - Validation Acc: 0.789
# Epoch 19/200 - Training Loss: 1.6889 - Validation Loss: 1.6755
#  Training Acc: 0.771 - Validation Acc: 0.784
#  Training Acc: 0.851 - Validation Acc: 0.857
# Epoch 45/200 - Training Loss: 1.5993 - Validation Loss: 1.6021
#  Training Acc: 0.861 - Validation Acc: 0.858
# Epoch 46/200 - Training Loss: 1.5936 - Validation Loss: 1.5971
#  Training Acc: 0.867 - Validation Acc: 0.864
# Epoch 47/200 - Training Loss: 1.5935 - Validation Loss: 1.5964
#  Training Acc: 0.867 - Validation Acc: 0.864
# Epoch 48/200 - Training Loss: 1.5898 - Validation Loss: 1.5981
#  Training Acc: 0.871 - Validation Acc: 0.862
# Epoch 49/200 - Training Loss: 1.5880 - Validation Loss: 1.5957
#  Training Acc: 0.872 - Validation Acc: 0.864
# Epoch 50/200 - Training Loss: 1.5871 - Validation Loss: 1.5933
#  Training Acc: 0.873 - Validation Acc: 0.867
# Epoch 51/200 - Training Loss: 1.5856 - Validation Loss: 1.5954
#  Training Acc: 0.875 - Validation Acc: 0.865
# Epoch 52/200 - Training Loss: 1.5838 - Validation Loss: 1.5948
#  Training Acc: 0.878 - Validation Acc: 0.865
# Epoch 53/200 - Training Loss: 1.5831 - Validation Loss: 1.5907
#  Training Acc: 0.878 - Validation Acc: 0.870
# Epoch 54/200 - Training Loss: 1.5832 - Validation Loss: 1.5928
#  Training Acc: 0.878 - Validation Acc: 0.867
# Epoch 55/200 - Training Loss: 1.5814 - Validation Loss: 1.5932
#  Training Acc: 0.879 - Validation Acc: 0.868
# Epoch 56/200 - Training Loss: 1.5785 - Validation Loss: 1.5894
#  Training Acc: 0.883 - Validation Acc: 0.872
# Epoch 57/200 - Training Loss: 1.5789 - Validation Loss: 1.5906
#  Training Acc: 0.882 - Validation Acc: 0.870
# Epoch 58/200 - Training Loss: 1.5792 - Validation Loss: 1.5894
#  Training Acc: 0.882 - Validation Acc: 0.871
# Epoch 59/200 - Training Loss: 1.5759 - Validation Loss: 1.5908
#  Training Acc: 0.885 - Validation Acc: 0.870
# Epoch 60/200 - Training Loss: 1.5773 - Validation Loss: 1.5905
#  Training Acc: 0.884 - Validation Acc: 0.870
# Epoch 61/200 - Training Loss: 1.5754 - Validation Loss: 1.5900
#  Training Acc: 0.885 - Validation Acc: 0.870
# Epoch 62/200 - Training Loss: 1.5750 - Validation Loss: 1.5898
#  Training Acc: 0.886 - Validation Acc: 0.870
# Epoch 63/200 - Training Loss: 1.5742 - Validation Loss: 1.5891
#  Training Acc: 0.887 - Validation Acc: 0.871
# Epoch 64/200 - Training Loss: 1.5728 - Validation Loss: 1.5869
#  Training Acc: 0.888 - Validation Acc: 0.874
# Stop training

# %%
x = np.linspace(1,curr_epoch,curr_epoch)
plt.plot(x, train_acc_list, label = "Train Accuracy")
plt.plot(x, val_acc_list, label = "Test Accuracy")
plt.legend()

# %% [markdown]
# Evaluate test accuracy

# %%
model.eval()
test_acc = 0
for images, labels in test_loader:
    images = images.to(device)
    labels = labels.to(device)
    predictions = model(images)
    accuracy = (torch.max(predictions, dim=-1, keepdim=True)[1].flatten() == labels).sum() / len(labels)
    test_acc += accuracy.item()
test_acc /= len(test_loader)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# Test accuracy: 0.873
